# %%
import pandas as pd
url_test = '/content/real-world-fuel-efficiency-1.csv'
url = "real-world-fuel-efficiency-1.csv"
df = pd.read_csv(url_test, skiprows = 0, skipfooter = 0, header=0, sep = ',')
df.head()
# Out:
#    YEAR       MAKE      MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0  2008      HONDA   CIVIC GX        Non-Hybrid         SEDAN
# 1  2008       FORD  CROWN VIC        Non-Hybrid         SEDAN
# 2  2008  CHEVROLET    EXPRESS        Non-Hybrid           VAN
# 3  2008       FORD      FOCUS        Non-Hybrid         SEDAN
# 4  2008       FORD     FUSION        Non-Hybrid         SEDAN
#
#    EPA RATING (CITY)  Vehicle Count  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# 0                 24              9                4459              221.0
# 1                 11              7               17162             1771.0
# 2                 13              1                 413               65.0
# 3                 24             49               13074              793.0
# 4                 18              5               29482             1813.0
#
#    EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# 0             185.79                       20.18
# ...

# %%
df
# Out:
#      YEAR          MAKE          MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0    2008         HONDA       CIVIC GX        Non-Hybrid         SEDAN
# 1    2008          FORD      CROWN VIC        Non-Hybrid         SEDAN
# 2    2008     CHEVROLET        EXPRESS        Non-Hybrid           VAN
# 3    2008          FORD          FOCUS        Non-Hybrid         SEDAN
# 4    2008          FORD         FUSION        Non-Hybrid         SEDAN
# ..    ...           ...            ...               ...           ...
# 101  2019     CHEVROLET        EXPRESS        Non-Hybrid           VAN
# 102  2019          FORD           F150        Non-Hybrid        PICKUP
# 103  2019          FORD           F250        Non-Hybrid        PICKUP
# 104  2019  FREIGHTLINER  SPRINTER 3500        Non-Hybrid           VAN
# 105  2019          FORD    TRANSIT VAN        Non-Hybrid           VAN
#
#      EPA RATING (CITY)  Vehicle Count  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
url = "real-world-fuel-efficiency-1.csv"



df=pd.read_csv(url)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106 entries, 0 to 105
# Data columns (total 14 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   YEAR                                106 non-null    int64
#  1   MAKE                                106 non-null    object
#  2   MODEL                               106 non-null    object
#  3   Hybrid/Non-Hybrid                   106 non-null    object
#  4   STANDARD TYPE                       106 non-null    object
#  5   EPA RATING (CITY)                   106 non-null    int64
#  6   Vehicle Count                       106 non-null    int64
#  7   TOTAL ACTUAL MILES                  106 non-null    int64
#  8   TOTAL ACTUAL FUEL                   106 non-null    float64
#  9   EPA EXPECTED FUEL                   106 non-null    float64
#  10  ACTUAL FUEL ECONOMY Geotab          106 non-null    float64
# ...

# %%
df.describe()
# Out:
#               YEAR  EPA RATING (CITY)  Vehicle Count  TOTAL ACTUAL MILES  \
# count   106.000000         106.000000     106.000000        1.060000e+02
# mean   2013.698113          23.254717      38.320755        1.742588e+05
# std       3.165799          11.495806      51.139128        2.837817e+05
# min    2008.000000           9.000000       1.000000        4.130000e+02
# 25%    2011.000000          15.000000      10.000000        3.217475e+04
# 50%    2014.000000          19.000000      20.500000        8.400450e+04
# 75%    2016.000000          28.000000      45.750000        1.800435e+05
# max    2019.000000          55.000000     327.000000        2.144639e+06
#
#        TOTAL ACTUAL FUEL  EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# count         106.000000         106.000000                  106.000000
# mean         8470.372642        6903.022358                   19.883491
# std          9212.284006        7641.761732                   12.329095
# ...

# %%
df5 = df[['Hybrid/Non-Hybrid', 'ESTIMATED FUEL COSTS PER GALLON']]
df5
# Out:
#     Hybrid/Non-Hybrid ESTIMATED FUEL COSTS PER GALLON
# 0          Non-Hybrid                      $   552.50
# 1          Non-Hybrid                    $   4,427.50
# 2          Non-Hybrid                      $   162.50
# 3          Non-Hybrid                    $   1,982.50
# 4          Non-Hybrid                    $   4,532.50
# ..                ...                             ...
# 101        Non-Hybrid                    $   2,212.50
# 102        Non-Hybrid                   $   13,547.50
# 103        Non-Hybrid                   $   13,622.50
# 104        Non-Hybrid                      $   740.00
# 105        Non-Hybrid                    $   5,827.50
#
# [106 rows x 2 columns]

# %%
veichle = df5['Hybrid/Non-Hybrid']=='Non-Hybrid'

# %%
veichle.sum()
# Out:
# 72

# %%
df6 = df5[veichle]

# %%
df6
# Out:
#     Hybrid/Non-Hybrid ESTIMATED FUEL COSTS PER GALLON
# 0          Non-Hybrid                      $   552.50
# 1          Non-Hybrid                    $   4,427.50
# 2          Non-Hybrid                      $   162.50
# 3          Non-Hybrid                    $   1,982.50
# 4          Non-Hybrid                    $   4,532.50
# ..                ...                             ...
# 101        Non-Hybrid                    $   2,212.50
# 102        Non-Hybrid                   $   13,547.50
# 103        Non-Hybrid                   $   13,622.50
# 104        Non-Hybrid                      $   740.00
# 105        Non-Hybrid                    $   5,827.50
#
# [72 rows x 2 columns]

# %%
hybrid = df5['Hybrid/Non-Hybrid']!='Non-Hybrid'

# %%
df7 =df5[hybrid]

# %%
df7.describe()
# Out:
#        Hybrid/Non-Hybrid ESTIMATED FUEL COSTS PER GALLON
# count                 34                              34
# unique                 1                              34
# top               Hybrid                    $   4,167.50
# freq                  34                               1

# %%
df7.sum()
# Out:
# Hybrid/Non-Hybrid                  HybridHybridHybridHybridHybridHybridHybridHybr...
# ESTIMATED FUEL COSTS PER GALLON    $   4,167.50$   63,632.50$   6,975.00$   21,82...
# dtype: object

# %%
df8 = df6['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '')
# Out:
# <ipython-input-24-ccd9f77aa679>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df8 = df6['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '')

# %%
df8
# Out:
# 0            552.50
# 1          4,427.50
# 2            162.50
# 3          1,982.50
# 4          4,532.50
#            ...
# 101        2,212.50
# 102       13,547.50
# 103       13,622.50
# 104          740.00
# 105        5,827.50
# Name: ESTIMATED FUEL COSTS PER GALLON, Length: 72, dtype: object

# %%
df9 = df6['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '').str.replace(',', '').astype(float)
# Out:
# <ipython-input-27-7c5bf2ff46a1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df9 = df6['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '').str.replace(',', '').astype(float)

# %%
df9
# Out:
# 0        552.5
# 1       4427.5
# 2        162.5
# 3       1982.5
# 4       4532.5
#         ...
# 101     2212.5
# 102    13547.5
# 103    13622.5
# 104      740.0
# 105     5827.5
# Name: ESTIMATED FUEL COSTS PER GALLON, Length: 72, dtype: float64

# %%
df5['ESTIMATED FUEL COSTS PER GALLON'] = df5['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '').str.replace(',', '').astype(float)
df5
# Out:
# <ipython-input-32-1adadf62441f>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   df5['ESTIMATED FUEL COSTS PER GALLON'] = df5['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '').str.replace(',', '').astype(float)
# <ipython-input-32-1adadf62441f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df5['ESTIMATED FUEL COSTS PER GALLON'] = df5['ESTIMATED FUEL COSTS PER GALLON'].str.replace('$', '').str.replace(',', '').astype(float)
#     Hybrid/Non-Hybrid  ESTIMATED FUEL COSTS PER GALLON
# 0          Non-Hybrid                            552.5
# ...

# %%
data = df5.groupby('Hybrid/Non-Hybrid')['ESTIMATED FUEL COSTS PER GALLON'].mean()

# %%
data.plot(kind = 'bar')
# Out:
# <Axes: xlabel='Hybrid/Non-Hybrid'>

# %% [markdown]
# CONCLUSÃO
#
# Nessa gráfico eu estou comparando a quantidade gasta em dinheiros com gasolina dos carros híbridos e não híbridos,e como se pode observar, a quantidade gasta com gasolina dos carros não híbridos é relativamente maior. Portanto, um carro híbrido é mais barato para abastecer, por conta de que tem que abastecer menos vezes.
