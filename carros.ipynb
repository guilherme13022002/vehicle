# %% [markdown]
# <a href="https://colab.research.google.com/github/guilherme13022002/vehicle/blob/main/carros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
url = "real-world-fuel-efficiency-1.csv"
df = pd.read_csv(url, skiprows = 0, skipfooter = 0, header=0, sep = ',')
df.head()
# Out:
#    YEAR       MAKE      MODEL Hybrid/Non-Hybrid STANDARD TYPE  \
# 0  2008      HONDA   CIVIC GX        Non-Hybrid         SEDAN
# 1  2008       FORD  CROWN VIC        Non-Hybrid         SEDAN
# 2  2008  CHEVROLET    EXPRESS        Non-Hybrid           VAN
# 3  2008       FORD      FOCUS        Non-Hybrid         SEDAN
# 4  2008       FORD     FUSION        Non-Hybrid         SEDAN
#
#    EPA RATING (CITY)  Vehicle Count  TOTAL ACTUAL MILES  TOTAL ACTUAL FUEL  \
# 0                 24              9                4459              221.0
# 1                 11              7               17162             1771.0
# 2                 13              1                 413               65.0
# 3                 24             49               13074              793.0
# 4                 18              5               29482             1813.0
#
#    EPA EXPECTED FUEL  ACTUAL FUEL ECONOMY Geotab  \
# 0             185.79                       20.18
# ...

# %%
# Out:
# <ipython-input-4-d4f16ae4c651>:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support skipfooter; you can avoid this warning by specifying engine='python'.
#   df = pd.read_csv(url, skiprows = 0, skipfooter = 1, header=0, sep = ';')
#         Casa                                      Lema   Status
# 0      STARK                   O inverno está chegando    Ativa
# 1  LANNISTER                             Ouça-me rugir    Ativa
# 2  TARGARYEN                             Fogo e Sangue    Ativa
# 3  BARATHEON                           Nossa é a fúria  Extinta
# 4     TYRELL                          Crescendo fortes  Extinta
# 5      TULLY                     Família, dever, honra    Ativa
# 6    MARTELL  Insubmissos, não curvados, não quebrados  Extinta
# 7    GREYJOY                          Nós não semeamos    Ativa
# 8      ARRYN                     Tão alto como a honra    Ativa
